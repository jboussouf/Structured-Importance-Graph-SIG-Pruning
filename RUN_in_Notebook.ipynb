# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r "/content/drive/MyDrive/test/SIG" "/content/"

# %%
import os
os.chdir('/content/SIG')

# %%
# !pip install -r requirements.txt

# %%
# !python evaluation_pipeline.py --dataset mnist
# Out:
# 2026-08-09 14:28:24,895 - INFO - --- Benchmarking Speedup: 2x on mnist (Ratio: 0.50) ---
# 2026-08-09 14:28:25,744 - INFO - Building computational graph...
# 2026-08-09 14:28:48,503 - INFO - Computing eigenvector centrality...
# 2026-08-09 14:32:58,097 - INFO - Propagating importance scores backward...
# 2026-08-09 14:33:02,872 - INFO - Applying structured pruning (ratio: 0.5)...
# 2026-08-09 14:33:03,002 - INFO - Pruned 13780/27560 nodes (50.00%)
# 2026-08-09 14:33:04,973 - INFO - [GPU] Building computational graph...
# 2026-08-09 14:33:28,396 - INFO - [GPU] Computing eigenvector centrality (NetworkX/CPU)...
# 2026-08-09 14:37:32,569 - INFO - [GPU] Propagating importance scores backward (GPU batched)...
# 2026-08-09 14:37:33,262 - INFO - [GPU] Applying structured pruning (ratio: 0.5)...
# 2026-08-09 14:37:34,136 - INFO - [GPU] Pruned 13780/27560 nodes (50.00%)
# 2026-08-09 14:37:36,052 - INFO - Applying Greedy GIS Pruning (k_iter=3)...
# ...

# %%
# !python ablation_studies.py
# Out:
# 2026-08-09 14:56:11,801 - INFO - Building computational graph...
# 2026-08-09 14:56:34,263 - INFO - Computing degree centrality...
# 2026-08-09 14:56:34,278 - INFO - Propagating importance scores backward...
# 2026-08-09 14:56:39,772 - INFO - Applying structured pruning (ratio: 0.5)...
# 2026-08-09 14:56:39,917 - INFO - Pruned 13780/27560 nodes (50.00%)
# 2026-08-09 14:56:40,495 - INFO - Building computational graph...
# 2026-08-09 14:57:04,494 - INFO - Computing betweenness centrality...
# 2026-08-09 14:57:04,494 - INFO - Using approximate betweenness centrality (k=500 of 27560 nodes)...
# 2026-08-09 15:04:57,529 - INFO - Propagating importance scores backward...
# 2026-08-09 15:05:03,563 - INFO - Applying structured pruning (ratio: 0.5)...
# 2026-08-09 15:05:03,662 - INFO - Pruned 13780/27560 nodes (50.00%)
# 2026-08-09 15:05:05,701 - INFO - Building computational graph...
# 2026-08-09 15:05:28,917 - INFO - Computing eigenvector centrality...
# ...

# %%
# !python generate_figures.py
# Out:
# Generating figures...
# /content/SIG/generate_figures.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_2x, x="Method", y="Pruning Time (s)", palette="viridis")
# Figures successfully generated in ./figures/
